# %%
# %matplotlib inline

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import gzip
import re
import json
import cmath

# %%
def parse_line(l):
    try:
        l = l.decode()
    except:
        print("Error on Line")
        print(l)
        return None
    if l[0] == '#': 
        return None
    if len(l) < 33:
        #print("ERROR: "+l)
        return None
    return {
        "task": re.sub("^ *", "", l[0:16]),
        "pid": int(re.sub(" +$", "", l[17:22])),
        "cpu": int(l[24:27]),
        "irq_off": l[29],
        "need_resched": l[30],
        "hardirq_softirq": l[31],
        "preempt_depth": int(l[32]),
        "timestamp": float(l[33:45]),
        "function": re.sub(":.*", "", l[48:])[:-1],
        "arguments": re.sub("[^:]+:", "", l[48:])[:-1]
    }

# %%
def load_log(tracefile):
    with gzip.open(tracefile) as f:
        return [
            line 
            for line in [parse_line(line) for line in f]
            if line != None
        ]

# %%
def query_state(trace):
    return [
        [line["timestamp"], 1 if re.match(".*(SQL_START|BDB_START|DELAY_end)", line["arguments"]) else 0, line["arguments"]]
        for line in trace
        if re.match(".*(DELAY_|SQL_|BDB_)", line["arguments"])
        and line["function"] == "tracing_mark_write"
        and line["task"] == "chmark_withjson"
    ]

# %%
def compute_deltas(trace):
    state_changes = query_state(trace)
    state_on = state_changes[0::2]
    state_off = state_changes[1::2]
    assert( len([x for x in state_on if x[1] != 1]) == 0)
    assert( len([x for x in state_off if x[1] != 0]) == 0)
    start_time = state_on[0][0]
    state_pairs = zip([x[0] for x in state_on], [x[0] for x in state_off])
    return [
        (x[0]-start_time, x[1]-x[0])
        for x in state_pairs
    ]

# %%
all_governors = [
    "conservative", 
    "interactive", 
    "ondemand", 
    "performance", 
    "youtube_conservative", 
    "youtube_interactive", 
    "youtube_ondemand", 
    "powersave", 
#    "userspace"
]

# %%
def load_deltas(tracefile):
    print("Loading "+tracefile)
    return np.array(compute_deltas(load_log(tracefile)))

# %%
def load_ops(opsfile):
    with open(opsfile) as f:
        benchmark = json.load(f)["benchmark"]
        return zip(
            range(0, len(benchmark)),
            [
                ( x["sql"].split(" ")[0] )
                for x in benchmark
                if x["op"] == "query"
            ]
        )

# %%
def load_ops_by_category(opsfile):
    result = {}
    for idx, event in load_ops(opsfile):
        if event not in result:
            result[event] = []
        result[event] += [ (idx, len(result[event])) ]
    return result
    
# load_ops_by_category("../files/json/log_timing/workload_a_timing_a.json")

# %%
def plot_ops(opsfile, ax = None):
    if ax == None:
        fig = plt.figure()
        ax = fig.add_subplot(111)
    ops = load_ops_by_category(opsfile)
    for event in ops:
        points = ops[event]
        scale = float(points[-1][1])
        ax.plot(
            [x[0] for x in points],
            [x[1] for x in points],
            label = event
        )
    ax.legend()

opsfiles = [
    "../files/json/log_timing/workload_"+x+"_timing_a.json"
    for x in ["a","b","c","d","e","f","ib","ic"]
]

fig = plt.figure(figsize = (10,10))
for i, opsfile in zip(range(0, len(opsfiles)), opsfiles):
    ax = fig.add_subplot(421+i)
    plot_ops(opsfile, ax)

# %%
def reduce(arr):
    result = {}
    for k, v in arr:
        if k not in result:
            result[k] = []
        result[k] += [v]
    return result

# %%
def label_deltas(deltas, opsfile):
    deltas = zip(load_ops(opsfile), deltas, range(0, len(deltas)))
    return reduce([
        (x[0][1], (x[2],x[1][1]))
        for x in deltas
    ])

# %%
all_workloads = [
    { "code" : "A", "source_code" : "A", "ops" : opsfiles[0] },  
    { "code" : "B", "source_code" : "B", "ops" : opsfiles[1] },  
    { "code" : "C", "source_code" : "C", "ops" : opsfiles[2] },  
    { "code" : "D", "source_code" : "D", "ops" : opsfiles[3] },  
    { "code" : "E", "source_code" : "E", "ops" : opsfiles[4] },  
    { "code" : "F", "source_code" : "F", "ops" : opsfiles[5] },  
    { "code" : "G", "source_code" : "IB", "ops" : opsfiles[6] },  
    { "code" : "H", "source_code" : "IC", "ops" : opsfiles[7] }
]

# %%
all_latencies = {}

# %%
for workload in all_workloads:
    code = workload["code"]
    if code not in all_latencies:
        all_latencies[code] = {
            "code" : workload["code"],
            "ops"  : workload["ops"],
            "latencies" : {}
        }
    for gov in all_governors:
        if gov not in all_latencies[code]["latencies"]:
            path = ""
            if gov.startswith("youtube_"):
                path = "../governor_traces/youtube_with/log_"+gov[8:]+"/YCSB_Workload"+workload["source_code"]+"_TimingAsql.log.gz"
            else:
                path = "../governor_traces/with_delaytags/log_"+gov+"/YCSB_Workload"+workload["source_code"]+"_TimingAsql.log.gz"
            all_latencies[code]["latencies"][gov] = load_deltas(path)
# Out:
# Loading ../governor_traces/with_delaytags/log_conservative/YCSB_WorkloadA_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_interactive/YCSB_WorkloadA_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_ondemand/YCSB_WorkloadA_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_performance/YCSB_WorkloadA_TimingAsql.log.gz
# Loading ../governor_traces/youtube_with/log_conservative/YCSB_WorkloadA_TimingAsql.log.gz
# Error on Line
# b'           <...>-7667  [001] ...2   294.884926: sched_switch: prev_comm=workqueue_truste\xf3\x1d prev_pid=7667 prev_prio=98 prev_state=D ==> next_comm=chmark_withjson next_pid=6855 next_prio=130\n'
# Loading ../governor_traces/youtube_with/log_interactive/YCSB_WorkloadA_TimingAsql.log.gz
# Loading ../governor_traces/youtube_with/log_ondemand/YCSB_WorkloadA_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_powersave/YCSB_WorkloadA_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_conservative/YCSB_WorkloadB_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_interactive/YCSB_WorkloadB_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_ondemand/YCSB_WorkloadB_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_performance/YCSB_WorkloadB_TimingAsql.log.gz
# Loading ../governor_traces/youtube_with/log_conservative/YCSB_WorkloadB_TimingAsql.log.gz
# Error on Line
# b'           <...>-5090  [001] ...2   354.125004: sched_switch: prev_comm=workqueue_truste\xe2\x13 prev_pid=5090 prev_prio=98 prev_state=D ==> next_comm=ExoPlayerImplIn next_pid=4698 next_prio=104\n'
# Error on Line
# b'           <...>-5111  [001] ...2   366.325008: sched_switch: prev_comm=workqueue_truste\xf7\x13 prev_pid=5111 prev_prio=98 prev_state=D ==> next_comm=MediaCodec_loop next_pid=4712 next_prio=118\n'
# Loading ../governor_traces/youtube_with/log_interactive/YCSB_WorkloadB_TimingAsql.log.gz
# Loading ../governor_traces/youtube_with/log_ondemand/YCSB_WorkloadB_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_powersave/YCSB_WorkloadB_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_conservative/YCSB_WorkloadC_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_interactive/YCSB_WorkloadC_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_ondemand/YCSB_WorkloadC_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_performance/YCSB_WorkloadC_TimingAsql.log.gz
# Loading ../governor_traces/youtube_with/log_conservative/YCSB_WorkloadC_TimingAsql.log.gz
# Loading ../governor_traces/youtube_with/log_interactive/YCSB_WorkloadC_TimingAsql.log.gz
# Loading ../governor_traces/youtube_with/log_ondemand/YCSB_WorkloadC_TimingAsql.log.gz
# Error on Line
# b'           <...>-5797  [001] ...2   489.585196: sched_switch: prev_comm=workqueue_truste\xa5\x16 prev_pid=5797 prev_prio=98 prev_state=D ==> next_comm=swapper/1 next_pid=0 next_prio=120\n'
# Error on Line
# b'           <...>-6376  [001] ...2   525.505570: sched_switch: prev_comm=workqueue_truste\xe8\x18 prev_pid=6376 prev_prio=98 prev_state=D ==> next_comm=chmark_withjson next_pid=5613 next_prio=130\n'
# Loading ../governor_traces/with_delaytags/log_powersave/YCSB_WorkloadC_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_conservative/YCSB_WorkloadD_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_interactive/YCSB_WorkloadD_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_ondemand/YCSB_WorkloadD_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_performance/YCSB_WorkloadD_TimingAsql.log.gz
# Loading ../governor_traces/youtube_with/log_conservative/YCSB_WorkloadD_TimingAsql.log.gz
# Error on Line
# b'           <...>-4855  [001] ...2   255.574291: sched_switch: prev_comm=workqueue_truste\xf7\x12 prev_pid=4855 prev_prio=98 prev_state=D ==> next_comm=swapper/1 next_pid=0 next_prio=120\n'
# Loading ../governor_traces/youtube_with/log_interactive/YCSB_WorkloadD_TimingAsql.log.gz
# Loading ../governor_traces/youtube_with/log_ondemand/YCSB_WorkloadD_TimingAsql.log.gz
# Error on Line
# b'           <...>-4850  [001] ...2   311.385100: sched_switch: prev_comm=workqueue_truste\xf2\x12 prev_pid=4850 prev_prio=98 prev_state=D ==> next_comm=swapper/1 next_pid=0 next_prio=120\n'
# Error on Line
# b'           <...>-5084  [001] ...2   317.335294: sched_switch: prev_comm=workqueue_truste\xdc\x13 prev_pid=5084 prev_prio=98 prev_state=D ==> next_comm=swapper/1 next_pid=0 next_prio=120\n'
# Loading ../governor_traces/with_delaytags/log_powersave/YCSB_WorkloadD_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_conservative/YCSB_WorkloadE_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_interactive/YCSB_WorkloadE_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_ondemand/YCSB_WorkloadE_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_performance/YCSB_WorkloadE_TimingAsql.log.gz
# Loading ../governor_traces/youtube_with/log_conservative/YCSB_WorkloadE_TimingAsql.log.gz
# Loading ../governor_traces/youtube_with/log_interactive/YCSB_WorkloadE_TimingAsql.log.gz
# Error on Line
# b'           <...>-6028  [001] ...2   654.876142: sched_switch: prev_comm=workqueue_truste\x8c\x17 prev_pid=6028 prev_prio=98 prev_state=D ==> next_comm=swapper/1 next_pid=0 next_prio=120\n'
# Loading ../governor_traces/youtube_with/log_ondemand/YCSB_WorkloadE_TimingAsql.log.gz
# Error on Line
# b'           <...>-19925 [001] ...2  3506.975929: sched_switch: prev_comm=workqueue_truste\xd5M prev_pid=19925 prev_prio=98 prev_state=D ==> next_comm=swapper/1 next_pid=0 next_prio=120\n'
# Loading ../governor_traces/with_delaytags/log_powersave/YCSB_WorkloadE_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_conservative/YCSB_WorkloadF_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_interactive/YCSB_WorkloadF_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_ondemand/YCSB_WorkloadF_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_performance/YCSB_WorkloadF_TimingAsql.log.gz
# Loading ../governor_traces/youtube_with/log_conservative/YCSB_WorkloadF_TimingAsql.log.gz
# Loading ../governor_traces/youtube_with/log_interactive/YCSB_WorkloadF_TimingAsql.log.gz
# Loading ../governor_traces/youtube_with/log_ondemand/YCSB_WorkloadF_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_powersave/YCSB_WorkloadF_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_conservative/YCSB_WorkloadIB_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_interactive/YCSB_WorkloadIB_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_ondemand/YCSB_WorkloadIB_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_performance/YCSB_WorkloadIB_TimingAsql.log.gz
# Loading ../governor_traces/youtube_with/log_conservative/YCSB_WorkloadIB_TimingAsql.log.gz
# Error on Line
# b'           <...>-7891  [001] ...2   286.284910: sched_switch: prev_comm=workqueue_truste\xd3\x1e prev_pid=7891 prev_prio=98 prev_state=D ==> next_comm=chmark_withjson next_pid=7097 next_prio=130\n'
# Loading ../governor_traces/youtube_with/log_interactive/YCSB_WorkloadIB_TimingAsql.log.gz
# Loading ../governor_traces/youtube_with/log_ondemand/YCSB_WorkloadIB_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_powersave/YCSB_WorkloadIB_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_conservative/YCSB_WorkloadIC_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_interactive/YCSB_WorkloadIC_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_ondemand/YCSB_WorkloadIC_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_performance/YCSB_WorkloadIC_TimingAsql.log.gz
# Loading ../governor_traces/youtube_with/log_conservative/YCSB_WorkloadIC_TimingAsql.log.gz
# Error on Line
# b'           <...>-7837  [001] ...2   334.485028: sched_switch: prev_comm=workqueue_truste\x9d\x1e prev_pid=7837 prev_prio=98 prev_state=D ==> next_comm=swapper/1 next_pid=0 next_prio=120\n'
# Error on Line
# b'           <...>-7887  [001] ...2   342.075049: sched_switch: prev_comm=workqueue_truste\xcf\x1e prev_pid=7887 prev_prio=98 prev_state=D ==> next_comm=swapper/1 next_pid=0 next_prio=120\n'
# Loading ../governor_traces/youtube_with/log_interactive/YCSB_WorkloadIC_TimingAsql.log.gz
# Loading ../governor_traces/youtube_with/log_ondemand/YCSB_WorkloadIC_TimingAsql.log.gz
# Loading ../governor_traces/with_delaytags/log_powersave/YCSB_WorkloadIC_TimingAsql.log.gz

# %%
def plot_one_workload(ax, i, latency_data, with_xlabel = True, with_ylabel = True):
    opsfile = latency_data["ops"]
    ax.semilogy()
    ax.set_ylim(4e-4,4e-1)
    if with_xlabel:
        ax.set_xlabel("Query Index")
    else:
        ax.get_xaxis().set_visible(False)
    if with_ylabel:
        ax.set_ylabel("Latency (s)")
    title = all_governors[i].replace("youtube_", "Loaded ").title()+" Governor"
    ax.set_title(title)
    labeled_deltas = label_deltas(latency_data["latencies"][all_governors[i]], opsfile)
    for q in ["SELECT", "UPDATE", "INSERT"]:
        if q in labeled_deltas:
            ax.scatter(
                [x[0] for x in labeled_deltas[q]],
                [x[1] for x in labeled_deltas[q]],
                s=10, label = q, marker = ('+' if q == "SELECT" else 'x')
            )
    ax.legend()
    

def plot_workload_latencies(latency_data):
    workload_title = "Workload "+latency_data["code"].upper()
    save_file = "workload_"+latency_data["code"].lower()+"_time_log_grid.pdf"
    fig = plt.figure( figsize = (16, 5) )
    for i in range(0,len(all_governors)):
        ax = fig.add_subplot(241+i)
        plot_one_workload(ax, i, latency_data, 
                          with_xlabel = (i >= 4), 
                          with_ylabel = (i % 4 == 0))
    fig.suptitle(workload_title)
    fig.savefig(save_file, bbox_inches='tight')
plot_workload_latencies(all_latencies["A"])

# %%
plot_workload_latencies(all_latencies["B"])

# %%
plot_workload_latencies(all_latencies["C"])

# %%
plot_workload_latencies(all_latencies["D"])

# %%
plot_workload_latencies(all_latencies["E"])

# %%
plot_workload_latencies(all_latencies["F"])

# %%
plot_workload_latencies(all_latencies["G"])

# %%
plot_workload_latencies(all_latencies["H"])

# %%
def plot_joint_workload_delta_histogram(latency_data):
    fig = plt.figure( figsize = (6, 4) )
    ax = fig.add_subplot(111)
    ax.semilogx()
    ax.set_xlabel("Latency (ms)")
    ax.set_ylabel("CDF")
    markers = 'x<^D+>vo'
    for i in range(0,len(all_governors)):
        if(all_governors[i] != "userspace"):
            curr_deltas = latency_data["latencies"][all_governors[i]]
            title = all_governors[i].replace("youtube_", "Load+").title()+" Governor"
            num_deltas = float(len(curr_deltas))
            ax.plot(
                sorted([x[1]*1000 for x in curr_deltas]),
                [x / num_deltas for x in range(0, len(curr_deltas))],
                marker=markers[i],
                markevery = 150,
                label = title
            )
    ax.legend()
    fig.suptitle("Workload "+latency_data["code"].upper())
    fig.savefig("workload_"+latency_data["code"].lower()+"_time_log_joint_hist.pdf", bbox_inches='tight')

all_codes = "ABCDEFGH"
for code in all_codes:
    print("workload_"+code.lower()+"_time_log_hist.pdf")
    plot_joint_workload_delta_histogram(all_latencies[code])
# Out:
# workload_a_time_log_hist.pdf
# workload_b_time_log_hist.pdf
# workload_c_time_log_hist.pdf
# workload_d_time_log_hist.pdf
# workload_e_time_log_hist.pdf
# workload_f_time_log_hist.pdf
# workload_g_time_log_hist.pdf
# workload_h_time_log_hist.pdf

# %%
grid_workload_order = "AFBCDEGH"
grid_gov_order = (
    [ "performance" ]
    + [x for x in all_governors if not x.startswith("youtube_") and x != "performance"] 
    + [x for x in all_governors if x.startswith("youtube_")]
)

def compute_metrics(code, gov):
    deltas = all_latencies[code]["latencies"][gov]
    latencies = sorted([ x[1] * 1000 for x in deltas ])
    start_time = deltas[0][0]
    end_time = deltas[-1][0] + deltas[-1][0]

    throughput = len(deltas) / float(end_time - start_time)
    median_latency = latencies[int(len(latencies) * 0.5)]
    worstcase_latency = latencies[int(len(latencies) * 0.95)]
    
    return ( throughput, median_latency, worstcase_latency )

metrics_grid = [
    [compute_metrics(code, gov) for code in grid_workload_order]
    for gov in grid_gov_order
]

# %%
def plot_metrics():
#     fig = plt.figure( figsize=(12,5) )
    cmap = "Spectral"
    for id, title, color, units in zip(
            range(0, 3), 
            ["Throughput", "Median Latency", "95 Percentile Latency"], 
            [cmap, cmap+"_r", cmap+"_r"],
            ["Operations per Second", "Milliseconds", "Milliseconds"]
        ):
        fig = plt.figure( figsize=(12,5) )
        data = [[col[id] for col in row] for row in metrics_grid]
        ax = fig.add_subplot(131+id)
        img = ax.imshow(data, cmap = color)
        fig.colorbar(img, orientation='horizontal', fraction=.1)
    #     ax.invert_yaxis()
        ax.set_xticks(range(0, len(grid_workload_order)))
        ax.tick_params(labeltop=True, labelbottom=False)
        ax.set_xticklabels(["Workload "+x for x in grid_workload_order], rotation = 90, ha = "left")
        ax.set_xlabel("\n\n"+units)
        ax.set_title(title+"\n\n\n\n\n")
        ax.set_yticklabels([()] + [ x.replace("youtube_", "Loaded ").title() for x in grid_gov_order])
        fig.savefig("performance_overview_"+title.replace(" ", "_").lower()+".pdf", bbox_inches='tight')
        ax.tick_params(labelleft=False)
        fig.savefig("performance_overview_"+title.replace(" ", "_").lower()+"_no_ylabels.pdf", bbox_inches='tight')
#     fig.savefig("performance_overview.pdf", bbox_inches='tight')

plot_metrics()

# %%
def plot_individual_workload_latencies(latency_data):
    workload_title = "Workload "+latency_data["code"].upper()
    for i in range(0,len(all_governors)):
        save_file = "workload_"+latency_data["code"].lower()+"_time_log_"+all_governors[i]+".pdf"
        print("Plotting "+save_file+"...")
        fig = plt.figure( figsize = (16, 6) )
        ax = fig.add_subplot(241+i)
        plot_one_workload(ax, i, latency_data)
        fig.savefig(save_file, bbox_inches='tight')
for code in "ABCDEFGH":
    plot_individual_workload_latencies(all_latencies[code])
# Out:
# Plotting workload_a_time_log_conservative.pdf...
# Plotting workload_a_time_log_interactive.pdf...
# Plotting workload_a_time_log_ondemand.pdf...
# Plotting workload_a_time_log_performance.pdf...
# Plotting workload_a_time_log_youtube_conservative.pdf...
# Plotting workload_a_time_log_youtube_interactive.pdf...
# Plotting workload_a_time_log_youtube_ondemand.pdf...
# Plotting workload_a_time_log_powersave.pdf...
# Plotting workload_b_time_log_conservative.pdf...
# Plotting workload_b_time_log_interactive.pdf...
# Plotting workload_b_time_log_ondemand.pdf...
# Plotting workload_b_time_log_performance.pdf...
# Plotting workload_b_time_log_youtube_conservative.pdf...
# Plotting workload_b_time_log_youtube_interactive.pdf...
# Plotting workload_b_time_log_youtube_ondemand.pdf...
# Plotting workload_b_time_log_powersave.pdf...
# Plotting workload_c_time_log_conservative.pdf...
# Plotting workload_c_time_log_interactive.pdf...
# Plotting workload_c_time_log_ondemand.pdf...
# Plotting workload_c_time_log_performance.pdf...
# Plotting workload_c_time_log_youtube_conservative.pdf...
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Plotting workload_c_time_log_youtube_interactive.pdf...
# Plotting workload_c_time_log_youtube_ondemand.pdf...
# Plotting workload_c_time_log_powersave.pdf...
# Plotting workload_d_time_log_conservative.pdf...
# Plotting workload_d_time_log_interactive.pdf...
# Plotting workload_d_time_log_ondemand.pdf...
# Plotting workload_d_time_log_performance.pdf...
# Plotting workload_d_time_log_youtube_conservative.pdf...
# Plotting workload_d_time_log_youtube_interactive.pdf...
# Plotting workload_d_time_log_youtube_ondemand.pdf...
# Plotting workload_d_time_log_powersave.pdf...
# Plotting workload_e_time_log_conservative.pdf...
# Plotting workload_e_time_log_interactive.pdf...
# Plotting workload_e_time_log_ondemand.pdf...
# Plotting workload_e_time_log_performance.pdf...
# Plotting workload_e_time_log_youtube_conservative.pdf...
# Plotting workload_e_time_log_youtube_interactive.pdf...
# Plotting workload_e_time_log_youtube_ondemand.pdf...
# Plotting workload_e_time_log_powersave.pdf...
# Plotting workload_f_time_log_conservative.pdf...
# Plotting workload_f_time_log_interactive.pdf...
# Plotting workload_f_time_log_ondemand.pdf...
# Plotting workload_f_time_log_performance.pdf...
# Plotting workload_f_time_log_youtube_conservative.pdf...
# Plotting workload_f_time_log_youtube_interactive.pdf...
# Plotting workload_f_time_log_youtube_ondemand.pdf...
# Plotting workload_f_time_log_powersave.pdf...
# Plotting workload_g_time_log_conservative.pdf...
# Plotting workload_g_time_log_interactive.pdf...
# Plotting workload_g_time_log_ondemand.pdf...
# Plotting workload_g_time_log_performance.pdf...
# Plotting workload_g_time_log_youtube_conservative.pdf...
# Plotting workload_g_time_log_youtube_interactive.pdf...
# Plotting workload_g_time_log_youtube_ondemand.pdf...
# Plotting workload_g_time_log_powersave.pdf...
# Plotting workload_h_time_log_conservative.pdf...
# Plotting workload_h_time_log_interactive.pdf...
# Plotting workload_h_time_log_ondemand.pdf...
# Plotting workload_h_time_log_performance.pdf...
# Plotting workload_h_time_log_youtube_conservative.pdf...
# Plotting workload_h_time_log_youtube_interactive.pdf...
# Plotting workload_h_time_log_youtube_ondemand.pdf...
# Plotting workload_h_time_log_powersave.pdf...
